# %%
import os
import pandas as pd

os.chdir('/home/nwong/chompsky/serial_chain/telephone-analysis-public')

from os.path import join, exists
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np

import load_runs
from new_models import prep_probs, sub_analysis_plots

import importlib

# 6/2 From Dr. Meylan 
# %load_ext rpy2.ipython

# %% [markdown]
# ## Load editTable information from Prep notebook

# %%
# Load the results of scoring per model

WORD_CHANGES_FOLDER = './intermediate_results/word_changes'
word_change_path = join(WORD_CHANGES_FOLDER, 'word_change_probs.csv')

all_changes_probs = prep_probs.load_word_changes(WORD_CHANGES_FOLDER)
MODEL_NAMES = list(all_changes_probs.keys())
# Quick check to make sure there are actual edits
assert not any(all_changes_probs_df.iloc[i]['sWord'] == all_changes_probs_df.iloc[i]['rWord']
    for all_changes_probs_df in all_changes_probs.values()
    for i in range(len(all_changes_probs_df))
    )

# %% [markdown]
# ## Analyses

# %% [markdown]
# R code
#
# 6/2 from Dr. Meylan's code and https://www.datanovia.com/en/lessons/how-to-do-a-t-test-in-r-calculation-and-reporting/how-to-do-paired-t-test-in-r/
#
# This source actually calls the code "independent t test" but they do a paired test, so it should be the dependent test?
#
# As supported here: http://www.sthda.com/english/wiki/paired-samples-t-test-in-r

# %%
def t_test_per_model(model_name, prob_df):
    
    this_model_prob_df = prob_df[model_name]
    
    
    # 6/2: https://www.kite.com/python/answers/how-to-drop-empty-rows-from-a-pandas-dataframe-in-python#:~:text=Use%20df.,contain%20NaN%20under%20those%20columns.
    this_model_prob_df = this_model_prob_df.dropna()
    
    print(f'******** For model {model_name}')
    # %R -i this_model_prob_df
    # %R orig <- this_model_prob_df$orig_prob
    # %R edited <- this_model_prob_df$edited_prob
    # %R result <- t.test(orig, edited, paired = TRUE)
    # %R print(result)

#6/2 note to self:
# If we ever upgrade pandas to a 1.x version,
# https://github.com/selik/xport/pull/38
# The upgrade will get rid of the warning "The error is: module 'pandas' has no attribute 'NA'"
# Warning is also present when running Aggregate

for model_name in all_changes_probs:
    t_test_per_model(model_name, all_changes_probs)
# Out:
# ******** For model gpt2_normal
#
# 	Paired t-test
#
# data:  orig and edited
# t = -1.2288, df = 539, p-value = 0.2197
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -0.022086432  0.005087818
# sample estimates:
# mean of the differences
#            -0.008499307
#
# ******** For model gpt2_medium
# /home/nwong/chompsky/serial_chain/telephone-analysis-public/telephone-env-3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:63: UserWarning: Error while trying to convert the column "code". Fall back to string conversion. The error is: module 'pandas' has no attribute 'NA'
#   % (name, str(e)))
# /home/nwong/chompsky/serial_chain/telephone-analysis-public/telephone-env-3/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:63: UserWarning: Error while trying to convert the column "sWord". Fall back to string conversion. The error is: module 'pandas' has no attribute 'NA'
#   % (name, str(e)))
# ...

# %%
# Violin plots

importlib.reload(sub_analysis_plots)

for use_neg_surprisal in [True, False]:
    all_model_dfs = sub_analysis_plots.gen_violin_plots(all_changes_probs, use_neg_surprisal)

    # 6/1: https://seaborn.pydata.org/generated/seaborn.violinplot.html

    score_type = 'surprisals' if use_neg_surprisal else 'probabilities'
    plt.title(f'Frequency of original and substituted word {score_type}')
    sns.violinplot(
        x = 'model_name', y = 'score',
        data = all_model_dfs,
        hue = 'is_original_prob',
        palette = 'muted',
        split = True
    )
    plt.show()

# %%
# Histogram of difference between original to edited word, per model

#word_change_len = len(all_changes_probs['gpt2_normal'])
#assert all(len(df) == word_change_len for df in all_changes_probs.values()), "The dataframes aren't all the same length"
#x_range = range(word_change_len)

plt.title('Histogram of differences in probability (edited - original)')
plt.xlabel('Positive surprisal')
plt.ylabel('Frequency')

for model_name in all_changes_probs:
    
    this_df = all_changes_probs[model_name]
    plt.hist(sub_analysis_plots.to_surprisal(this_df['edited_prob']) - sub_analysis_plots.to_surprisal(this_df['orig_prob']),
             label = model_name, alpha = 0.3)
    plt.legend()
